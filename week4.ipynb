# %%
import math

# %%
import numpy as np

# %%
# Define your list of numbers
numbers = [12, 6, 8, 3, 19]

# Calculate mean
mean = np.mean(numbers)

# Calculate median
median = np.median(numbers)

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 9.6
# Median: 8.0

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('insurance.csv')

# Display the DataFrame
print(df)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Calculate mean
mean = np.mean('bmi')

# Calculate median
median = np.median('bmi')

print("Mean:", mean)
print("Median:", median)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Calculate mean
# ----> 2 mean = np.mean('bmi')
#       4 # Calculate median
#       5 median = np.median('bmi')
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:118, in _mean(a, axis, dtype, out, keepdims, where)
#     115         dtype = mu.dtype('f4')
#     116         is_float16_result = True
# --> 118 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
#
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('insurance.csv')

# Extract the column of interest (e.g., 'bmi')
bmi_column = df['bmi']

# Calculate mean
mean = bmi_column.mean()

# Calculate median
median = bmi_column.median()

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 30.66339686098655
# Median: 30.4

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('insurance.csv')

# Extract the column of interest (e.g., 'bmi')
charges_column = df['charges']

# Calculate mean
mean = charges_column.mean()

# Calculate median
median = charges_column.median()

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 13270.422265141257
# Median: 9382.033

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.describe(insurance.csv)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('insurance.csv')

# Use describe() function to get summary statistics
summary_stats = df.describe()

print(summary_stats)
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import numpy as np
# Define your list of numbers
numbers = [4, 1, 2, 3, 6, 0, 5]

# Calculate mean
mean = np.mean(numbers)

# Calculate median
median = np.median(numbers)

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 3.0
# Median: 3.0

# %%
# Define your list of numbers
numbers = [1, -2, -1, 0, 3, -3, 2]

# Calculate mean
mean = np.mean(numbers)

# Calculate median
median = np.median(numbers)

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 0.0
# Median: 0.0

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('insurance.csv')

# Calculate coefficient of variation for 'age'
cv_age = df['age'].std() / df['age'].mean()*100

# Calculate coefficient of variation for 'bmi'
cv_bmi = df['bmi'].std() / df['bmi'].mean()*100

print("Coefficient of Variation for Age:", cv_age)
print("Coefficient of Variation for BMI:", cv_bmi)
# Out:
# Coefficient of Variation for Age: 35.8353132682499
# Coefficient of Variation for BMI: 19.88751259139792

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Read the CSV file into a DataFrame
df = pd.read_csv('insurance.csv')

# Calculate mean and standard deviation for 'age' and 'bmi'
mean_age = df['age'].mean()
std_age = df['age'].std()

mean_bmi = df['bmi'].mean()
std_bmi = df['bmi'].std()

# Generate normal distribution for 'age'
x_age = np.linspace(mean_age - 3*std_age, mean_age + 3*std_age, 100)
pdf_age = norm.pdf(x_age, mean_age, std_age)

# Generate normal distribution for 'bmi'
x_bmi = np.linspace(mean_bmi - 3*std_bmi, mean_bmi + 3*std_bmi, 100)
pdf_bmi = norm.pdf(x_bmi, mean_bmi, std_bmi)

# Plot the normal distributions
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(x_age, pdf_age, label='Normal Distribution')
plt.hist(df['age'], bins=30, density=True, alpha=0.5, color='g', label='Actual Data')
plt.title('Normal Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Probability Density')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(x_bmi, pdf_bmi, label='Normal Distribution')
plt.hist(df['bmi'], bins=30, density=True, alpha=0.5, color='b', label='Actual Data')
plt.title('Normal Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Probability Density')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0
std_dev = 1

# Generate some random data from a normal distribution
data = np.random.normal(mean, std_dev, 1000)

# Calculate the cumulative distribution function (CDF) at a specific point
x_value = 0.5
cdf_value = norm.cdf(x_value, mean, std_dev)
print(f"CDF at x={x_value}: {cdf_value}")

# Calculate the probability density function (PDF) at a specific point
pdf_value = norm.pdf(x_value, mean, std_dev)
print(f"PDF at x={x_value}: {pdf_value}")

# Plot the PDF and CDF
x = np.linspace(-4, 4, 1000)
plt.figure(figsize=(10, 5))
plt.plot(x, norm.pdf(x, mean, std_dev), label='PDF')
plt.plot(x, norm.cdf(x, mean, std_dev), label='CDF')
plt.title('Normal Distribution PDF and CDF')
plt.xlabel('x')
plt.ylabel('Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# CDF at x=0.5: 0.6914624612740131
# PDF at x=0.5: 0.3520653267642995

# %%
from scipy.stats import norm

# Parameters for the normal distribution
mean_height = 170  # Mean height in cm
std_dev = 7  # Standard deviation of height in cm

# Calculate the probability that height is less than 165 cm
p_less_than_165 = norm.cdf(165, mean_height, std_dev)*100
print("P(x < 165 cm):", p_less_than_165)

# Calculate the probability that height is between 165 and 170 cm
p_between_165_170 = norm.cdf(170, mean_height, std_dev)*100 - norm.cdf(165, mean_height, std_dev)*100
print("P(165 < x < 170 cm):", p_between_165_170)

# Find the height corresponding to the tallest 10% of the population
tallest_10_percent_height = norm.ppf(0.9, mean_height, std_dev)
print("Height of the tallest 10% of the population:", tallest_10_percent_height)
# Out:
# P(x < 165 cm): 23.75252620269765
# P(165 < x < 170 cm): 26.24747379730235
# Height of the tallest 10% of the population: 178.9708609588122

# %%
import pandas as pd
import scipy.stats as stats

# Step 1: Load the dataset
data = pd.read_csv('insurance.csv')

# Step 2: Calculate mean and standard deviation for 'charges'
mean_charges = data['charges'].mean()
std_charges = data['charges'].std(ddof=1)  # Use ddof=1 for sample standard deviation

print(mean_charges, std_charges)
# Out:
# 13270.422265141257 12110.011236694001

# %%
# margin of error
z_critical = stats.norm.ppf(q=0.975)  # Get the Z-critical value (for 95% confidence)
margin_of_error = z_critical * (std_charges / (n ** 0.5))
print(margin_of_error)
# Out:
# 648.8802869120973

# %%
# Step 5: Calculate the confidence interval
lower_bound = mean_charges - margin_of_error
upper_bound = mean_charges + margin_of_error

print(f"95% Confidence Interval: {lower_bound} to {upper_bound}")
# Out:
# 95% Confidence Interval: 12621.54197822916 to 13919.302552053354

# %%
# Select a random sample of 15 patients from the dataset
sample_data = data['charges'].sample(n=15)

# Calculate sample mean and standard deviation
sample_mean = sample_data.mean()
sample_std = sample_data.std(ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(sample_data)

# Determine the degrees of freedom
degrees_of_freedom = sample_size - 1

# Find the t-critical value for the 95% confidence level
confidence_level = 0.95
t_critical = stats.t.ppf(q = (1 + confidence_level) / 2, df=degrees_of_freedom)

# Calculate the margin of error
margin_of_error_t = t_critical * (sample_std / (sample_size ** 0.5))

# Calculate the confidence interval
lower_bound_t = sample_mean - margin_of_error_t
upper_bound_t = sample_mean + margin_of_error_t

(sample_mean, sample_std, lower_bound_t, upper_bound_t)
# Out:
# (11341.954632, 6334.262680466533, 7834.156880135865, 14849.752383864135)
