# %%
# Define the expression
expression = 2 + (3**2) - 2 * (4 + ((4 * 2)**2)) / ((6 / 3) * 2)

# Print the result
print(expression)
# Out:
# -23.0

# %%
# Use type() to check what data type you are dealing with
type(.4e7)
# Out:
# float

# %%
# The function int() makes an interger of an input value. The function needs 1 argument
int(1.56)
# Out:
# 1

# %%
# If a function need more arguments, they are seperated with a comma
max(7, 3)
# Out:
# 7

# %%
# create own function def f(x)
def f(x):
  return 2 * x + 1

x_values = [0, 1, 2, 3]

for x in x_values:
  y = f(x)
  print (y)
# Out:
# 1
# 3
# 5
# 7

# %%
# First you import a package. Then you can use functions within this package eg.
import math
math.sqrt(7921)
# Out:
# 89.0

# %%
from sympy.plotting import plot

def f(x):
  return x**3 + 15 * x +300
y = f(x)
print (y)
# Out:
# 372

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols ('x')
f = x**3 + 15 * x + 300
plot (f)

# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols ('x')
f = 2*x + 5
plot (f)

# %%
expression = 7**5
print (expression)
# Out:
# 16807

# %%
# A logarithm is the inverse operation of an exponant
# It finds the power/exponent for a specific number and base, rules on page 17 of Nield
from math import log
x = log(8, 2)
print (x)
# Out:
# 3.0

# %%
type(62.6738)
# Out:
# float

# %%
10**7*10**-5
# Out:
# 100.00000000000001

# %%
81**(1/2)
# Out:
# 9.0

# %%
81**0.5
# Out:
# 9.0
