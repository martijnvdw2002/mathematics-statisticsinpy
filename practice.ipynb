# %%
my_value = 2 + 3 * (3+2)**2 / 15
print(my_value)
# Out:
# 7.0

# %%
my_value = 2 * (3 + 2)**2 / 5 - 4
print(my_value)
# Out:
# 6.0

# %%
# make use of parentels for clarity
my_value = 2 * ((3 + 2)**2 / 5) - 4
print(my_value)
# Out:
# 6.0

# %%
x = int(5)
product = 3 * x
print(product)
# Out:
# 15

# %%
def f(x):
 return 2 * x + 1
x_values = [0, 1, 2, 3]
for x in x_values:
 y = f(x)
 print(f(x))
# Out:
# 1
# 3
# 5
# 7

# %%
from sympy import *
x = symbols('x')
f = 2*x + 1
plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d
x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %%
summation = sum(2*i for i in range(1,6))
print(summation)
# Out:
# 30
